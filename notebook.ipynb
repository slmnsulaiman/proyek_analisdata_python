# %% [markdown]
# # Proyek Analisis Data: E Commerce
# - **Nama:** Sulaiman
# - **Email:** sulaimanlaisul@gmail.com
# - **ID Dicoding:** sulaimanlai

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 ( Bagaimana distribusi metode pembayaran yang digunakan oleh pelanggan dalam pembelian mereka? )
# - Pertanyaan 2 ( Kategori produk mana yang menghasilkan pendapatan tertinggi dalam periode tertentu?)

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
file_path = "dataset/customers_dataset.csv"
customer_df = pd.read_csv(file_path)
customer_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
file_path = "dataset/geolocation_dataset.csv"
geolocation_df = pd.read_csv(file_path)
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
file_path = "dataset/order_items_dataset.csv"
order_items_df = pd.read_csv(file_path)
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
file_path = "dataset/order_payments_dataset.csv"
order_payments_df = pd.read_csv(file_path)
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
file_path = "dataset/order_reviews_dataset.csv"
order_reviews_df = pd.read_csv(file_path)
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
file_path = "dataset/orders_dataset.csv"
orders_df = pd.read_csv(file_path)
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
file_path ="dataset/product_category_name_translation.csv"
product_category_name_translation_df = pd.read_csv(file_path)
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
file_path = "dataset/products_dataset.csv"
product_df = pd.read_csv(file_path)
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
file_path ="dataset/sellers_dataset.csv"
sales_df = pd.read_csv(file_path)
sales_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ## menilai tabel customer_df

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customer_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi :", customer_df.duplicated().sum())
# Out:
# Jumlah duplikasi : 0

# %%
customer_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# menilai tabel geolacation_df

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah duplikasi : ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi :  261831

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# Menilai tabel Order_items

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi : ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi :  0

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# menilai tabel order_payment

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah Duplikasi :", order_payments_df.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# menilai tabel orders_reviews_df

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("jumlah duplikasi ", order_reviews_df.duplicated().sum())
# Out:
# jumlah duplikasi  0

# %%
order_reviews_df.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# ## menilai tabel orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print('Jumlah duplikasi', orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi 0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# ## menilai tabel product_category_name_translation_df

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_name_translation_df.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("jumlah duplikasi :", product_category_name_translation_df.duplicated().sum())
# Out:
# jumlah duplikasi : 0

# %%
product_category_name_translation_df.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ## menilai tabel product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi :", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi : 0

# %%
product_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ## menilai tabel sales_df

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sales_df.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("jumlah duplikasi :", sales_df.duplicated().sum())
# Out:
# jumlah duplikasi : 0

# %%
sales_df.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ## membersihkan tabel geolacation_df

# %% [markdown]
# duplicate

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
print("jumlah duplikasi : ", geolocation_df.duplicated().sum())
# Out:
# jumlah duplikasi :  0

# %% [markdown]
# ## Membersihkan tabel order_items_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# memperbaiki tipe data

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
    order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ## Membersihkan tabel order_review_df

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# missing value

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_reviews_df.fillna(value="Recomendo", inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# ## membersihkan tabel orders_df

# %% [markdown]
# tipe data

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
datetime_columns = ["order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(5)
# memory usage: 6.1+ MB

# %% [markdown]
# missing value

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: count, Length: 90733, dtype: int64

# %%
orders_df.fillna(value="2018-02-27 04:31:10", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99441 non-null  object
#  5   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(5)
# memory usage: 6.1+ MB

# %% [markdown]
# ## membersihkan tabel product_df

# %% [markdown]
# missing value

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product_df[product_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
product_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
product_df.fillna(value="cama_mesa_banho", inplace=True)
# Out:
# C:\Users\Sulaiman\AppData\Local\Temp\ipykernel_13400\618281409.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'cama_mesa_banho' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   product_df.fillna(value="cama_mesa_banho", inplace=True)

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_lenght         32951 non-null  object
#  3   product_description_lenght  32951 non-null  object
#  4   product_photos_qty          32951 non-null  object
#  5   product_weight_g            32951 non-null  object
#  6   product_length_cm           32951 non-null  object
#  7   product_height_cm           32951 non-null  object
#  8   product_width_cm            32951 non-null  object
# dtypes: object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# ## explore customer_df

# %%
customer_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 2602   3943ab310b409df9d58ab083922f6382  457cdfab71a4eb8f8b5956ebcb14d42f
# 81185  c3f03ad00c3a59d7e1be8376fcd6e9f2  dcfc9c44bf4471c67137fac8b54bce59
# 82332  778593c83b75c7519025543b07a41073  d061ca43cf50773dd3d5d96c091324e0
# 51411  18a6f45b5b6ac7558018737eeec04faa  f0dcfe8e166f2704249218997df96dbb
# 34915  2b784701261a664c8a3fd4ce83c9679c  5806bc4407f79e8de3fa8324c3313476
#
#        customer_zip_code_prefix          customer_city customer_state
# 2602                      64052               teresina             PI
# 81185                     22221         rio de janeiro             RJ
# 82332                     39800          teofilo otoni             MG
# 51411                      9862  sao bernardo do campo             SP
# 34915                      7844        franco da rocha             SP

# %%
customer_df.describe(include= "all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customer_df.customer_id.is_unique
# Out:
# True

# %%
customer_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customer_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# eksplore geolation_df

# %%
geolocation_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 562159                        31110       -19.910276       -43.937369
# 935599                        89870       -26.852664       -52.989929
# 254704                        11451       -23.943690       -46.298425
# 740366                        60130        -3.748120       -38.518099
# 128069                         5409       -23.559361       -46.672678
#
#        geolocation_city geolocation_state
# 562159   belo horizonte                MG
# 935599      pinhalzinho                SC
# 254704          guaruja                SP
# 740366        fortaleza                CE
# 128069        sao paulo                SP

# %%
geolocation_df.describe(include="all")
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                 738332.000000    738332.000000    738332.000000
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   38316.086800       -20.998353       -46.461098
# std                    30632.496675         5.892315         4.393705
# min                     1001.000000       -36.605374      -101.466766
# 25%                    12600.000000       -23.603061       -48.867822
# 50%                    29144.000000       -22.873588       -46.647278
# 75%                    65950.000000       -19.923336       -43.836974
# max                    99990.000000        45.065933       121.105394
#
#        geolocation_city geolocation_state
# count            738332            738332
# ...

# %% [markdown]
# ## eksplore order_item_df

# %%
order_items_df.sample(5)
# Out:
#                                order_id  order_item_id  \
# 72583  a5849d6f70582d4c5217bac6616a45fa              1
# 36622  531a74ff9a6617b0cae88c4b67646988              1
# 52971  788dadfe475fc16d5e7562f1a5fa8e82              1
# 11557  1a479eca71e8e8efb68b0968a43d8fb1              1
# 49768  7117ea59ab9bdbf381b1a880eb25b07c              1
#
#                              product_id                         seller_id  \
# 72583  b75a056d7d03227c3a3b60e9ccf518c9  3f995f07c49d0d55a99d5c54957f7d81
# 36622  a0b7d5a992ccda646f2d34e418fff5a0  95f83f51203c626648c875dd41874c7f
# 52971  71a62950e363cbba0816448a733a58e0  c6bda72e4dbf5c5866b13cb1810c6d03
# 11557  cf3c40851efb1d10b475156c902b4765  080102cd0a76b09e0dcf55fcacc60e05
# 49768  fb09ab0eb676b60b254250a28fd46e10  ea566164622c6b439516ab18062c42cd
#
#       shipping_limit_date  price  freight_value
# 72583 2018-08-17 03:23:59   59.0          15.51
# 36622 2018-02-08 09:30:19   69.9          14.60
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# ## eksplore order_payment_df

# %%
order_payments_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 33878  749990ae992d496bb8ad6972705298f3                   2      voucher
# 85657  85390f5003d9b2084c226bac317cca79                   1  credit_card
# 79295  626f6424e635c6341bfddf7d53bf3746                   1  credit_card
# 21136  20b36768bef1e17c7b54f6982a5801d6                   1       boleto
# 35003  ea1a388e3dfe8c2f47be2bc881a6669b                   1       boleto
#
#        payment_installments  payment_value
# 33878                     1          77.42
# 85657                    10         290.76
# 79295                    10         125.92
# 21136                     1         140.33
# 35003                     1         134.45

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ## eksplore order_review

# %%
order_reviews_df.sample(5)
# Out:
#                               review_id                          order_id  \
# 77063  347e829413c962bc32f540369db931dd  2279b7f227b450166adadca909462947
# 1539   8409d68d3635df372440875e8d668226  68a9fce416cc56ce2950c32b7e70138e
# 83304  12d3ce4e7a5f507828a620c4de639830  dfe1a1cff6291723d37ed8f60e12d5c9
# 82133  6824aee90ae8ad2ede2abfda0f2c83a7  84ca1ce0b502782387a2afcd5a8e9356
# 64512  78d1190a2809cc4fbd29712c323e57e6  c0a1f5741cc59aa9709c497f176d6dc5
#
#        review_score review_comment_title  \
# 77063             5            Recomendo
# 1539              5            Recomendo
# 83304             5            Recomendo
# 82133             4            Recomendo
# 64512             3            Recomendo
#
#                                   review_comment_message review_creation_date  \
# 77063  Adorei o produto e chegou antes do prazo, exce...  2017-12-19 00:00:00
# 1539                                           Recomendo  2017-11-28 00:00:00
# ...

# %%
order_reviews_df.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %%
order_reviews_df.groupby(by="review_score").order_id.nunique().sort_values(ascending=False)
# Out:
# review_score
# 5    57076
# 4    19098
# 1    11393
# 3     8160
# 2     3148
# Name: order_id, dtype: int64

# %% [markdown]
# ## eksplore order_df

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 97958  d2d740a1b76ee640f76fba030363144e  a5aaba3df38fc92cd86da4b9781e1d47
# 76522  0a31cb63d4483ffbef1d5503752a0b5d  d9e90748b0092bb0f5417edccf34783b
# 25473  d701dc60f61795a62070fa2494b6691a  5c87184371002d49e08b9ac10eb96647
# 80548  d4bf1286601648f75bf89839e7991d17  991b6e88c5c983654861053d33fd7e16
# 88007  9f6792a082a71398109a94b8039d3c07  bbb2c952b4db558ca2132fd705d6bc5f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 97958    delivered      2018-04-23 11:20:32  2018-04-24 19:17:15
# 76522    delivered      2017-07-18 13:44:30  2017-07-18 13:55:18
# 25473    delivered      2018-01-05 19:15:37  2018-01-05 19:27:42
# 80548    delivered      2017-07-18 09:21:45  2017-07-18 09:30:19
# 88007    delivered      2017-10-20 10:39:57  2017-10-20 10:49:36
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
orders_df.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99441
# ...

# %% [markdown]
# ## eksplore product_category_name_translation_df

# %%
product_category_name_translation_df.sample(5)
# Out:
#              product_category_name product_category_name_english
# 62                 casa_conforto_2                home_comfort_2
# 28         fashion_roupa_masculina         fashion_male_clothing
# 14                      brinquedos                          toys
# 20                           audio                         audio
# 50  fashion_underwear_e_moda_praia       fashion_underwear_beach

# %%
product_category_name_translation_df.describe(include='all')
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ## eksplore product_df

# %%
product_df.sample(5)
# Out:
#                              product_id        product_category_name  \
# 28679  98fa920be965878f7c44da75d4cb6ddc  fashion_bolsas_e_acessorios
# 2327   ddf08c1f4da4aeb900e20da32cee2c50                        artes
# 5477   3c28d10ea65fbafd9792027334cf4544             moveis_decoracao
# 14916  97c6f57881227cc97e87be3e34f108f8                esporte_lazer
# 4253   14b47a66430c89500f18cdaaef9e0c21                   brinquedos
#
#       product_name_lenght product_description_lenght product_photos_qty  \
# 28679                54.0                      650.0                4.0
# 2327                 44.0                      134.0                1.0
# 5477                 57.0                     1586.0                6.0
# 14916                56.0                     2580.0                2.0
# 4253                 49.0                     1230.0                7.0
#
#       product_weight_g product_length_cm product_height_cm product_width_cm
# ...

# %%
product_df.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
#
#         product_name_lenght product_description_lenght  product_photos_qty  \
# count               32951.0                      32951             32951.0
# unique                 67.0                       2961                20.0
# top                    60.0            cama_mesa_banho                 1.0
# freq                 2182.0                        610             16489.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count            32951.0            32951.0            32951.0
# unique            2205.0              100.0              103.0
# top                200.0               16.0               10.0
# ...

# %% [markdown]
# ## eksplore seller_df

# %%
sales_df.sample(5)
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 802   596849622429351f47b32e6cae1055ff                    8710
# 156   024b564ae893ce8e9bfa02c10a401ece                    3280
# 1380  aae5e7b457a3c72ee230a47d98fceda5                   83040
# 682   96e5dc09087bad639b4ee193104ec2e5                   28660
# 2580  fec8cd45395b3cb0c2b173d7739706a1                   12270
#
#               seller_city seller_state
# 802       mogi das cruses           SP
# 156             sao paulo           SP
# 1380  sao jose dos pinhas           PR
# 682            bom jardim           RJ
# 2580             jambeiro           SP

# %%
sales_df.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# ## eksplore orders_df dan order_payments_df

# %% [markdown]
# ### menggabungkan data

# %%
payment_order_df = pd.merge(
    left=orders_df,
    right=order_payments_df,
    how="left",
    left_on='order_id',
    right_on='order_id'
)

payment_order_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
payment_order_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
payment_order_df.groupby(by="payment_type").agg({
    "order_id" : "nunique",
    "payment_value" : "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#               order_id  payment_value
# payment_type
# credit_card      76505    12542084.19
# boleto           19784     2869361.27
# voucher           3866      379436.87
# debit_card        1528      217989.79
# not_defined          3           0.00

# %% [markdown]
# ## eksplore order_item , order_review dan product

# %% [markdown]
# ### menggabubgkan data

# %%
item_review_df = pd.merge(
    left=order_items_df,
    right=order_reviews_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)

# %%
item_review_product = pd.merge(
    left=item_review_df,
    right=product_df,
    how='left',
    left_on='product_id',
    right_on='product_id'
)
item_review_product.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  \
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
item_review_product.groupby(by="product_category_name").agg({
    "product_id" : "nunique",
    "price" : "sum"
})
# Out:
#                            product_id      price
# product_category_name
# agro_industria_e_comercio          74   72530.47
# alimentos                          82   29393.41
# alimentos_bebidas                 104   15270.47
# artes                              55   24202.64
# artes_e_artesanato                 19    1814.01
# ...                               ...        ...
# sinalizacao_e_seguranca            93   21509.23
# tablets_impressao_imagem            9    7528.41
# telefonia                        1134  323839.40
# telefonia_fixa                    116   59622.99
# utilidades_domesticas            2335  634542.60
#
# [73 rows x 2 columns]

# %% [markdown]
# ## Eksplore all data

# %%
main_df = pd.merge(
    left=payment_order_df,
    right=item_review_product,
    how='left',
    left_on='order_id',
    right_on='order_id'
)
main_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
main_df.groupby(by=["payment_type", "product_category_name"]).agg({

    "order_id" : "nunique",
    "price" : "sum"
})
# Out:
#                                         order_id     price
# payment_type product_category_name
# boleto       agro_industria_e_comercio        51  20552.30
#              alimentos                        99   5371.19
#              alimentos_bebidas                55   2753.79
#              artes                            46  10650.53
#              artes_e_artesanato                7    565.67
# ...                                          ...       ...
# voucher      sinalizacao_e_seguranca           3    283.17
#              tablets_impressao_imagem          3    311.90
#              telefonia                       157  15266.05
#              telefonia_fixa                    9   2304.10
#              utilidades_domesticas           286  42727.06
#
# [270 rows x 2 columns]

# %%
main_df.groupby(by=["review_score", "review_comment_title"]).agg({
    "order_id" : "sum",
    "product_id" : "sum"
}).sort_values(by="review_score", ascending=False)
# Out:
#                                                                                order_id  \
# review_score review_comment_title
# 5.0          🔟                                         a8bb77ab67213461d5c632d41df4fafd
#              Jogo de toalha                            9958682e9a3eea5beb7a32fde4612f65
#              Igual na foto                             6ddb004a75be2f9f5ff513839665267d
#              Imagem da imagem falsa                    1bb74bdf991ecc937ab8901c6b412a24
#              Impecável                                 7a2c45e504da96aebfc8a8268e49b920
# ...                                                                                 ...
# 1.0          PÉSSIMO SERVIÇO                           836f9b5adb4fe06d8980fb71fa06b691
#              Péssima                  bf866aa88acb3c2595d0627c7a6bedf702c8da4642d8bb...
#              Péssima                  81539e7eb97d9fba708603ac8f00b6c9ee43fa4abdcd5f...
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana distribusi metode pembayaran yang digunakan oleh pelanggan dalam pembelian mereka?

# %%
payment_distribution = main_df.groupby('payment_type')['payment_value'].count().reset_index()
plt.figure(figsize=(10, 5))
sns.barplot(x='payment_type', y='payment_value', data=payment_distribution)
plt.title('Jumlah Pembelian Berdasarkan Metode Pembayaran')
plt.xlabel('Metode Pembayaran')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Kategori produk mana yang menghasilkan pendapatan tertinggi dalam periode tertentu?

# %%
revenue_per_category = main_df.groupby('product_category_name')['price'].sum().reset_index()


top_5_revenue_categories = revenue_per_category.sort_values(by='price', ascending=False).head(5)

# Visualisasi dengan grafik batang
plt.figure(figsize=(12, 6))
sns.barplot(x='product_category_name', y='price', data=top_5_revenue_categories)
plt.title('5 Kategori Produk dengan Total Pendapatan Tertinggi')
plt.xlabel('Kategori Produk')
plt.ylabel('Total Pendapatan')
plt.xticks(rotation=45)
plt.show()

# %%
main_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 (Kesimpulan dari analisis ini menunjukkan bahwa terdapat variasi signifikan dalam jumlah transaksi berdasarkan jenis metode pembayaran yang digunakan oleh pelanggan. Dari grafik yang dihasilkan, terlihat bahwa beberapa metode pembayaran, seperti kartu kredit dan dompet digital, menunjukkan popularitas yang jauh lebih tinggi dibandingkan metode lainnya, mencerminkan preferensi pelanggan yang cenderung beralih ke pembayaran digital.
# Tren ini menandakan bahwa pelanggan semakin memilih kemudahan dan kecepatan dalam bertransaksi, sementara metode tradisional seperti transfer bank semakin jarang digunakan. Hal ini berdampak pada strategi pemasaran yang harus disesuaikan dengan preferensi tersebut. Misalnya, perusahaan dapat merancang program diskon atau insentif khusus untuk mendorong penggunaan metode pembayaran yang lebih populer, sehingga dapat meningkatkan tingkat konversi dan pendapatan.
# Selain itu, memperluas pilihan metode pembayaran yang tersedia dan memperbaiki pengalaman pengguna untuk metode yang kurang populer juga dapat menjadi langkah yang bijak. Dengan mengidentifikasi dan memanfaatkan tren ini, perusahaan tidak hanya dapat meningkatkan transaksi tetapi juga membangun loyalitas pelanggan yang lebih kuat.)
#
#
# - Conclution pertanyaan 2 (Analisis kategori produk mengungkapkan bahwa terdapat beberapa kategori yang mencatatkan pendapatan tertinggi dalam periode tertentu. Dengan menghitung total pendapatan per kategori dan mengidentifikasi lima kategori teratas, kita dapat menentukan kategori mana yang paling menguntungkan dan menjadi pendorong utama pendapatan perusahaan.
# Dari grafik yang dihasilkan, terlihat jelas perbandingan pendapatan antar kategori, memudahkan pemangku keputusan untuk memahami tren pasar. Kategori yang menunjukkan pendapatan tertinggi dapat menjadi fokus dalam strategi pemasaran, sehingga perusahaan dapat meningkatkan promosi dan penawaran pada kategori tersebut untuk lebih menarik pelanggan.
# Sebaliknya, kategori dengan pendapatan rendah perlu dianalisis lebih lanjut untuk memahami penyebabnya. Apakah disebabkan oleh kurangnya minat pelanggan, kurangnya visibilitas produk, atau faktor lain? Langkah yang dapat diambil termasuk meningkatkan pemasaran, melakukan inovasi produk, atau bahkan mempertimbangkan untuk menghentikan produk yang kurang menguntungkan. Dengan informasi ini, perusahaan dapat membuat keputusan yang lebih strategis dalam pengelolaan produk dan alokasi sumber daya untuk memaksimalkan pendapatan.)
